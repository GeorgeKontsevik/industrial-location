# %%
from network_construction import NetworkConstruction
import pandas as pd
import pickle

# %%
path = '/home/gk/code/migration_project/'

# %%
vacancies = pd.read_csv(path + "vacancy_unique_cities.csv")
cv = pd.read_csv(path + "curricula_vitae_unique.csv")
responses = pd.read_csv(path + "responses.csv", sep=";")
cv_cities = pd.read_csv(path + "curricula_vitae_cities.csv")
cv_years = pd.read_csv(path + "curricula_vitae_years.csv")
kladr_2021 = pd.read_csv(path + "kladr.csv")
organizations = pd.read_csv(path + "organizations.csv", delimiter=";")

with open(path + "orgs_from_dadata_all.pkl", "rb") as f:
    org_cities = pickle.load(f)
org_cities = pd.DataFrame(org_cities)
org_cities = pd.json_normalize(org_cities.iloc[:, 0])

specialists = pd.read_csv('/home/gk/code/migration_project/specialists/specialists_table.csv')
ontology = pd.read_csv('/home/gk/Downloads/ontology.csv')
cv = pd.read_csv(path + "curricula_vitae_unique.csv")
# Out:
# /tmp/ipykernel_63284/2264843180.py:3: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   responses = pd.read_csv(path + "responses.csv", sep=";")
# /tmp/ipykernel_63284/2264843180.py:7: DtypeWarning: Columns (36,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   organizations = pd.read_csv(path + "organizations.csv", delimiter=";")

# %%
ontology
# Out:
#                             Отрасль Уровень образования  \
# 0               Добыча нефти и газа                 СПО
# 1               Добыча нефти и газа                 СПО
# 2               Добыча нефти и газа                 СПО
# 3               Добыча нефти и газа                 СПО
# 4               Добыча нефти и газа                 СПО
# ..                              ...                 ...
# 246  Электроника и микроэлектроника                  ВО
# 247  Электроника и микроэлектроника                  ВО
# 248  Электроника и микроэлектроника                  ВО
# 249  Электроника и микроэлектроника                  ВО
# 250  Электроника и микроэлектроника                  ВО
#
#                   Специальность Код направления
# 0          Оператор, аппаратчик        21.01.05
# 1          Оператор, аппаратчик        21.01.16
# 2          Оператор, аппаратчик        21.02.18
# 3                     Монтажник        21.01.06
# 4                     Монтажник        21.01.14
# ..                          ...             ...
# 246         Инженер-конструктор        11.03.03
# 247  Специалист по сертификации        27.03.01
# 248                    Технолог        11.03.04
# 249                    Технолог        11.03.03
# 250         Инженер по качеству        27.03.02
#
# [251 rows x 4 columns]

# %%
G, responses2 = NetworkConstruction.run_pipeline(
    responses,
    vacancies,
    kladr_2021,
    organizations,
    org_cities,
    cv_years,
    cv_cities,
    cv,
    ontology,
    specialists,
    years=list(range(2018, 2022)),
    group=['Монтажник'],
    return_responses=True
)
# Out:
# /home/gk/code/migration_project/repo2/industrial-location/graph_calcs/network_construction.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   responses.loc[:, "year"] = responses["date_creation"].apply(
# 100%|██████████| 429/429 [00:00<00:00, 2902.25it/s]

# %%
responses2
# Out:
#         date_creation                          id_candidate  \
# 8376       2019-07-15  c12f2790-beb1-11e5-9eda-0163a9ae3d01
# 9313       2020-06-03  1e2649a0-8b7d-11ea-98d3-239861b1f67b
# 10234      2021-10-07  82783890-24cb-11eb-83b1-25bddbcbae91
# 10235      2021-09-15  82783890-24cb-11eb-83b1-25bddbcbae91
# 10236      2021-09-15  82783890-24cb-11eb-83b1-25bddbcbae91
# ...               ...                                   ...
# 1331057    2020-06-09  c58a11b0-7c1c-11ea-80d4-736ab11edb0c
# 1331235    2018-08-27  eaad0560-b569-11e6-89c7-4376a32b3f45
# 1332806    2021-07-09  3e76c350-da33-11eb-9a39-a75f74b7b031
# 1333645    2018-04-21  b7104000-62e0-11e5-9ba8-239645b044d5
# 1334230    2020-08-04  143f4ef0-a400-11ea-a6c8-ef76bd2a03c1
#
#                                         id_cv  \
# 8376     2ff598b0-9ce1-11e9-879d-e37b4be0b9ed
# 9313     84497c10-8b7e-11ea-98d3-239861b1f67b
# 10234    8a2efa80-f8d1-11eb-9288-69632329477c
# 10235    8a2efa80-f8d1-11eb-9288-69632329477c
# 10236    8a2efa80-f8d1-11eb-9288-69632329477c
# ...                                       ...
